# %%
import pandas as pd
from taskcode import gps_plotter
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = gps_plotter.load_tasks()
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550

# %%
df.head()
# Out:
#              id  node_id  position_fom position_update_timestamp  position_x  \
# 773738  5086182       23            50 2016-02-23 16:06:38+00:00        -448
# 773747  5086191       23            50 2016-02-23 16:06:39+00:00        -432
# 773753  5086197       23            50 2016-02-23 16:06:40+00:00        -448
# 773760  5086204       23            50 2016-02-23 16:06:41+00:00        -432
# 773768  5086212       23            50 2016-02-23 16:06:42+00:00        -432
#
#         position_y  position_z  sublocation_id       name  \
# 773738       34208        1008               1  Plumber 2
# 773747       34208        1008               1  Plumber 2
# 773753       34208        1008               1  Plumber 2
# 773760       34208        1008               1  Plumber 2
# 773768       34208        1008               1  Plumber 2
#
#                               start_time      ...      ntask_6_completed  \
# 773738  2016-02-23 16:06:37.494084+00:00      ...                      0
# 773747  2016-02-23 16:06:37.494084+00:00      ...                      0
# 773753  2016-02-23 16:06:37.494084+00:00      ...                      0
# 773760  2016-02-23 16:06:37.494084+00:00      ...                      0
# 773768  2016-02-23 16:06:37.494084+00:00      ...                      0
#
#         ntask_7_completed  ntask_8_completed  ntask_9_completed  \
# 773738                  0                  0                  1
# 773747                  0                  0                  1
# 773753                  0                  0                  1
# 773760                  0                  0                  1
# 773768                  0                  0                  1
#
#        ntask_10_completed  ntask_11_completed  quantile  time_delta  \
# 773738                  3                   1        63         1.0
# 773747                  3                   1        63         1.0
# 773753                  3                   1        63         1.0
# 773760                  3                   1        63         1.0
# 773768                  3                   1        63         1.0
#
#         quantile_diff  new_quantile
# 773738            0.0            63
# 773747            0.0            63
# 773753            0.0            63
# 773760            0.0            63
# 773768            0.0            63
#
# [5 rows x 31 columns]

# %%
df = df.sort_values(by = 'task_label', ascending = True)
sns.lmplot('position_x', 'position_y', data = df, hue = 'task_label', fit_reg = False)

# %%
sns.boxplot(x = 'task_label', y = 'position_x', data = df)

# %%
sns.boxplot(x = 'task_label', y = 'position_y', data = df)
